# %% [markdown]
# Here we'll use the data sets that are up to 2011 to try to predict who the next hall of famers will be. More goes into picking Hall of Fame player than pure statistics, but we'll see what feature correlate to a person getting selected.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # viz
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, precision_score, recall_score

# %matplotlib inline

# %% [markdown]
# ## Read in the data ##
# Load up the master data which has most of the information we'll use and we'll also look at the awards data to potentially try to merge that in.

# %%
master_df = pd.read_csv('../input/Master.csv')
master_df.head()
# Out:
#     playerID coachID hofID firstName    lastName nameNote         nameGiven  \
# 0  aaltoan01     NaN   NaN     Antti       Aalto      NaN             Antti
# 1  abbeybr01     NaN   NaN     Bruce       Abbey      NaN             Bruce
# 2  abbotge01     NaN   NaN    George      Abbott      NaN      George Henry
# 3  abbotre01     NaN   NaN       Reg      Abbott      NaN  Reginald Stewart
# 4  abdelju01     NaN   NaN    Justin  Abdelkader      NaN               NaN
#
#    nameNick  height  weight    ...     birthDay birthCountry  birthState  \
# 0       NaN    73.0   210.0    ...          4.0      Finland         NaN
# 1       NaN    73.0   185.0    ...         18.0       Canada          ON
# 2  Preacher    67.0   153.0    ...          3.0       Canada          ON
# 3       NaN    71.0   164.0    ...          4.0       Canada          MB
# 4       NaN    73.0   195.0    ...         25.0          USA          MI
#
#       birthCity  deathYear  deathMon  deathDay  deathCountry deathState  \
# 0  Lappeenranta        NaN       NaN       NaN           NaN        NaN
# 1       Toronto        NaN       NaN       NaN           NaN        NaN
# 2      Synenham        NaN       NaN       NaN           NaN        NaN
# 3      Winnipeg        NaN       NaN       NaN           NaN        NaN
# 4      Muskegon        NaN       NaN       NaN           NaN        NaN
#
#    deathCity
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 31 columns]

# %%
awards_df = pd.read_csv('../input/AwardsPlayers.csv')
awards_df.head()
# Out:
#     playerID     award  year lgID note  pos
# 0  malonjo01  Art Ross  1917  NHL  NaN  NaN
# 1  cleghod01  Art Ross  1918  NHL  NaN  NaN
# 2  malonjo01  Art Ross  1919  NHL  NaN  NaN
# 3  lalonne01  Art Ross  1920  NHL  NaN  NaN
# 4  broadpu01  Art Ross  1921  NHL  NaN  NaN

# %% [markdown]
# ## Cut out columns we care about ##
#
# Reduce the columns down to a smaller set of things we will use to predict a future hall of famer. Specifically focusing on things like country they were born, height, weight, shootCatch, position, length of career.

# %%
master_df = master_df[['playerID', 'birthCountry', 'hofID', 'firstName', 'lastName', 'height', 'weight', 'shootCatch', 'firstNHL', 'lastNHL', 'pos']]
master_df.head()
# Out:
#     playerID birthCountry hofID firstName    lastName  height  weight  \
# 0  aaltoan01      Finland   NaN     Antti       Aalto    73.0   210.0
# 1  abbeybr01       Canada   NaN     Bruce       Abbey    73.0   185.0
# 2  abbotge01       Canada   NaN    George      Abbott    67.0   153.0
# 3  abbotre01       Canada   NaN       Reg      Abbott    71.0   164.0
# 4  abdelju01          USA   NaN    Justin  Abdelkader    73.0   195.0
#
#   shootCatch  firstNHL  lastNHL pos
# 0          L    1997.0   2000.0   C
# 1          L       NaN      NaN   D
# 2          L    1943.0   1943.0   G
# 3          L    1952.0   1952.0   C
# 4          L    2007.0   2011.0   L

# %% [markdown]
# ## Basic info on column data available ##
# Peek into the datatypes and null status of all the different columns to see how we might need to clean up this data.

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7761 entries, 0 to 7760
# Data columns (total 11 columns):
# playerID        7520 non-null object
# birthCountry    7396 non-null object
# hofID           366 non-null object
# firstName       7748 non-null object
# lastName        7761 non-null object
# height          7334 non-null float64
# weight          7336 non-null float64
# shootCatch      7048 non-null object
# firstNHL        6851 non-null float64
# lastNHL         6851 non-null float64
# pos             7447 non-null object
# dtypes: float64(4), object(7)
# memory usage: 667.0+ KB

# %% [markdown]
# # Feature creation and data cleanup #
# Using the columns we care about, we'll just drop any records that contain null values to clean up the dataset. In a future version, we could get creative on filling these nulls with averages or other values.

# %%
master_df = master_df.dropna(subset=['playerID', 'birthCountry', 'height', 'weight', 'shootCatch', 'firstNHL', 'lastNHL'])
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6562 entries, 0 to 7760
# Data columns (total 11 columns):
# playerID        6562 non-null object
# birthCountry    6562 non-null object
# hofID           214 non-null object
# firstName       6562 non-null object
# lastName        6562 non-null object
# height          6562 non-null float64
# weight          6562 non-null float64
# shootCatch      6562 non-null object
# firstNHL        6562 non-null float64
# lastNHL         6562 non-null float64
# pos             6562 non-null object
# dtypes: float64(4), object(7)
# memory usage: 615.2+ KB

# %% [markdown]
# - Add a new column 'nhlLength' that will have the duration in years they played
# - Add a 0/1 flag for if that player made the HoF
# - Combine first/last name into one column

# %%
master_df["nhlLength"] = master_df["lastNHL"] - master_df["firstNHL"] + 1
master_df["isInHf"] = np.where(master_df['hofID'].notnull(), 1, 0)
master_df["fullName"] = master_df["firstName"] + ' ' + master_df["lastName"]

# %% [markdown]
# ### Merge in Awards Count for Player
# Assuming winning awards contributes to probability that a player makes the HoF, we'll aggregate the number of awards each player earned and merge it into our master dataset.

# %%
awards_df.head()
# Out:
#     playerID     award  year lgID note  pos
# 0  malonjo01  Art Ross  1917  NHL  NaN  NaN
# 1  cleghod01  Art Ross  1918  NHL  NaN  NaN
# 2  malonjo01  Art Ross  1919  NHL  NaN  NaN
# 3  lalonne01  Art Ross  1920  NHL  NaN  NaN
# 4  broadpu01  Art Ross  1921  NHL  NaN  NaN

# %% [markdown]
# Aggregate the count by playerID

# %%
awards_count_df = awards_df[['playerID', 'award']].groupby(['playerID'], as_index=False).count().sort_values(by='award', ascending=False)
awards_count_df = awards_count_df.rename(columns={'award':'awardCount'})
awards_count_df.head(25)
# Out:
#       playerID  awardCount
# 204  gretzwa01          51
# 245   howego01          36
# 323  lemiema01          28
# 45   bourqra01          26
# 429    orrbo01          26
# 251   hullbo01          25
# 328  lidstni01          21
# 216  hasekdo01          20
# 506    roypa01          18
# 260   jagrja01          18
# 56   brodema01          18
# 215  harvedo01          18
# 155  esposph01          17
# 387  mikitst01          16
# 431  ovechal01          16
# 210   hallgl01          16
# 491  richama01          15
# 449  plantja01          15
# 301  laflegu01          15
# 20   belivje01          14
# 281  kellyre01          13
# 40   bossymi01          13
# 136  drydeke01          13
# 85   chelich01          13
# 521  sawchte01          12

# %% [markdown]
# There is a reason he's called the Great One...
#
# Merge the two data frames together with a left outer join and then fill any null's with a 0

# %%
master_df = pd.merge(master_df, awards_count_df, how='left', on='playerID')
master_df['awardCount'] = master_df['awardCount'].fillna(0)
master_df.tail(25)
# Out:
#        playerID    birthCountry hofID firstName     lastName  height  weight  \
# 6537   zentja01             USA   NaN     Jason         Zent    71.0   204.0
# 6538  zettehe01          Sweden   NaN    Henrik   Zetterberg    71.0   195.0
# 6539  zettela01          Sweden   NaN      Lars  Zetterstrom    73.0   198.0
# 6540  zettlro01          Canada   NaN       Rob      Zettler    75.0   200.0
# 6541  zezelpe01          Canada   NaN     Peter        Zezel    71.0   220.0
# 6542  zhamnal01          Russia   NaN      Alex      Zhamnov    73.0   204.0
# 6543  zharkvl01          Russia   NaN  Vladimir      Zharkov    73.0   200.0
# 6544  zherdni01         Ukraine   NaN   Nikolai      Zherdev    74.0   197.0
# 6545  zhitnal01         Ukraine   NaN    Alexei      Zhitnik    71.0   225.0
# 6546  zholtse01          Latvia   NaN    Sergei      Zholtok    74.0   197.0
# 6547  zidlima01  Czech Republic   NaN     Marek     Zidlicky    71.0   190.0
# 6548  zieglth01     Switzerland   NaN    Thomas      Ziegler    71.0   174.0
# 6549  zigommi01          Canada   NaN      Mike    Zigomanis    73.0   200.0
# 6550  zingedw01          Canada   NaN    Dwayne       Zinger    76.0   216.0
# 6551  zinovse01          Russia   NaN    Sergei     Zinovjev    70.0   185.0
# 6552  zizkato01  Czech Republic   NaN     Tomas        Zizka    73.0   198.0
# 6553  zmoledo01             USA   NaN      Doug       Zmolek    74.0   222.0
# 6554  zoborma01          Canada   NaN     Marty    Zoborosky    70.0   180.0
# 6555  zombori01             USA   NaN      Rick        Zombo    73.0   202.0
# 6556  zubovil01          Russia   NaN      Ilja        Zubov    71.0   211.0
# 6557  zubovse01          Russia   NaN    Sergei        Zubov    73.0   198.0
# 6558  zubruda01       Lithuania   NaN   Dainius       Zubrus    77.0   225.0
# 6559   zukemi01          Canada   NaN      Mike         Zuke    72.0   180.0
# 6560  zunicru01             USA   NaN      Rudy       Zunich    69.0   170.0
# 6561  zyuzian01          Russia   NaN    Andrei       Zyuzin    73.0   208.0
#
#      shootCatch  firstNHL  lastNHL pos  nhlLength  isInHf           fullName  \
# 6537          L    1996.0   1998.0   L        3.0       0         Jason Zent
# 6538          L    2002.0   2011.0   L       10.0       0  Henrik Zetterberg
# 6539          L    1978.0   1978.0   D        1.0       0   Lars Zetterstrom
# 6540          L    1988.0   2001.0   D       14.0       0        Rob Zettler
# 6541          L    1984.0   1998.0   C       15.0       0        Peter Zezel
# 6542          L    1992.0   2005.0   C       14.0       0       Alex Zhamnov
# 6543          L    2009.0   2011.0   R        3.0       0   Vladimir Zharkov
# 6544          R    2003.0   2010.0   R        8.0       0    Nikolai Zherdev
# 6545          L    1992.0   2007.0   D       16.0       0     Alexei Zhitnik
# 6546          R    1992.0   2003.0   C       12.0       0     Sergei Zholtok
# 6547          R    2003.0   2011.0   D        9.0       0     Marek Zidlicky
# 6548          L    2000.0   2000.0   C        1.0       0     Thomas Ziegler
# 6549          R    2002.0   2010.0   C        9.0       0     Mike Zigomanis
# 6550          L    2003.0   2003.0   D        1.0       0      Dwayne Zinger
# 6551          L    2003.0   2003.0   C        1.0       0    Sergei Zinovjev
# 6552          L    2002.0   2003.0   D        2.0       0        Tomas Zizka
# 6553          L    1992.0   1999.0   D        8.0       0        Doug Zmolek
# 6554          R    1944.0   1944.0   D        1.0       0    Marty Zoborosky
# 6555          R    1984.0   1995.0   D       12.0       0         Rick Zombo
# 6556          L    2007.0   2008.0   C        2.0       0         Ilja Zubov
# 6557          R    1992.0   2008.0   D       17.0       0       Sergei Zubov
# 6558          L    1996.0   2011.0   R       16.0       0     Dainius Zubrus
# 6559          R    1978.0   1985.0   C        8.0       0          Mike Zuke
# 6560          L    1943.0   1943.0   D        1.0       0        Rudy Zunich
# 6561          L    1997.0   2007.0   D       11.0       0      Andrei Zyuzin
#
#       awardCount
# 6537         0.0
# 6538         3.0
# 6539         0.0
# 6540         0.0
# 6541         0.0
# 6542         1.0
# 6543         0.0
# 6544         0.0
# 6545         0.0
# 6546         0.0
# 6547         0.0
# 6548         0.0
# 6549         0.0
# 6550         0.0
# 6551         0.0
# 6552         0.0
# 6553         0.0
# 6554         0.0
# 6555         0.0
# 6556         0.0
# 6557         1.0
# 6558         0.0
# 6559         0.0
# 6560         0.0
# 6561         0.0

# %% [markdown]
# ## General Data Exploration

# %%
master_df.describe()
# Out:
#             height       weight     firstNHL      lastNHL    nhlLength  \
# count  6562.000000  6562.000000  6562.000000  6562.000000  6562.000000
# mean     71.964035   190.180128  1978.612313  1984.103322     6.491009
# std       2.300590    18.266095    23.759232    24.231722     5.098630
# min      63.000000   125.000000  1917.000000  1917.000000     1.000000
# 25%      70.000000   180.000000  1967.000000  1973.000000     2.000000
# 50%      72.000000   190.000000  1984.000000  1990.000000     5.000000
# 75%      74.000000   201.000000  1997.000000  2003.000000    10.000000
# max      81.000000   265.000000  2009.000000  2011.000000    34.000000
#
#             isInHf   awardCount
# count  6562.000000  6562.000000
# mean      0.032612     0.317434
# std       0.177632     1.677913
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       1.000000    51.000000

# %%
master_df.describe(include=['O'])
# Out:
#          playerID birthCountry       hofID firstName lastName shootCatch  \
# count        6562         6562         214      6562     6562       6562
# unique       6562           46         214      1106     4440          3
# top     richest01       Canada  brimsfr01h      Mike    Smith          L
# freq            1         4688           1       167       55       4300
#
#          pos       fullName
# count   6562           6562
# unique     9           6511
# top        D  Bill McCreary
# freq    1952              2

# %% [markdown]
# Where are most of the HoF's born?

# %%
master_df[['birthCountry', 'isInHf']].groupby(['birthCountry'], 
          as_index=False).sum().sort_values(by='isInHf', ascending=False).head(10)
# Out:
#       birthCountry  isInHf
# 5           Canada     195
# 40             USA       9
# 29          Russia       3
# 38          Taiwan       1
# 30        Scotland       1
# 7   Czech Republic       1
# 9          England       1
# 10         Finland       1
# 31        Slovakia       1
# 36          Sweden       1

# %% [markdown]
# What % of players from those countries make the HoF?

# %%
master_df[['birthCountry', 'isInHf']].groupby(['birthCountry'], 
          as_index=False).mean().sort_values(by='isInHf', ascending=False).head(10)
# Out:
#       birthCountry    isInHf
# 38          Taiwan  1.000000
# 30        Scotland  0.052632
# 9          England  0.050000
# 5           Canada  0.041596
# 29          Russia  0.018634
# 31        Slovakia  0.015873
# 40             USA  0.010286
# 10         Finland  0.006369
# 7   Czech Republic  0.005000
# 36          Sweden  0.004717

# %%
pd.crosstab(master_df['birthCountry'], master_df['isInHf'])
# Out:
# isInHf                0    1
# birthCountry
# Austria               6    0
# Belarus               7    0
# Belgium               1    0
# Brazil                2    0
# Brunei Darussalam     1    0
# Canada             4493  195
# Croatia               1    0
# Czech Republic      199    1
# Denmark               7    0
# England              19    1
# Finland             156    1
# France                5    0
# Germany              23    0
# Haiti                 1    0
# Indonesia             1    0
# Ireland               6    0
# Italy                 3    0
# Jamaica               1    0
# Japan                 2    0
# Kazakhstan            9    0
# Korea                 1    0
# Latvia               17    0
# Lebanon               1    0
# Lithuania             2    0
# Netherlands           1    0
# Nigeria               1    0
# Norway                5    0
# Paraguay              1    0
# Poland                6    0
# Russia              158    3
# Scotland             18    1
# Slovakia             62    1
# Slovenia              1    0
# South Africa          1    0
# South Korea           1    0
# South Wales           1    0
# Sweden              211    1
# Switzerland          15    0
# Taiwan                0    1
# Tanzania              1    0
# USA                 866    9
# USSR                 12    0
# Ukraine              17    0
# Venezuela             2    0
# Wales                 2    0
# Yugoslavia            2    0

# %% [markdown]
# Do they shoot left or right?

# %%
master_df[['shootCatch', 'isInHf']].groupby(['shootCatch'], 
          as_index=False).count().sort_values(by='isInHf', ascending=False)
# Out:
#   shootCatch  isInHf
# 1          L    4300
# 2          R    2261
# 0          B       1

# %% [markdown]
# Let's change that 'B' to a 'L' since 'L' is the most common

# %%
master_df.loc[master_df['shootCatch'] == 'B', 'shootCatch'] = 'L'
master_df[['shootCatch', 'isInHf']].groupby(['shootCatch'], 
          as_index=False).count().sort_values(by='isInHf', ascending=False)
# Out:
#   shootCatch  isInHf
# 0          L    4301
# 1          R    2261

# %% [markdown]
# Do certain positions make the HoF more than others?

# %%
master_df[['pos', 'isInHf']].groupby(['pos'], 
          as_index=False).count().sort_values(by='isInHf', ascending=False)
# Out:
#    pos  isInHf
# 1    D    1952
# 0    C    1415
# 5    L    1281
# 8    R    1228
# 4    G     644
# 3    F      39
# 2  D/L       1
# 6  L/C       1
# 7  L/D       1

# %% [markdown]
# Let's cleanup the players that have two positions listed only using the first one listed

# %%
master_df.loc[master_df['pos'] == 'L/D', 'pos'] = 'L'
master_df.loc[master_df['pos'] == 'D/L', 'pos'] = 'D'
master_df.loc[master_df['pos'] == 'L/C', 'pos'] = 'L'
#master_df.loc[master_df['pos'] == 'L', 'pos'] = 'F'
#master_df.loc[master_df['pos'] == 'R', 'pos'] = 'F'
master_df.loc[master_df['pos'] == 'F', 'pos'] = 'L'
master_df[['pos', 'isInHf']].groupby(['pos'], 
          as_index=False).mean().sort_values(by='isInHf', ascending=False)
# Out:
#   pos    isInHf
# 2   G  0.045031
# 0   C  0.044523
# 1   D  0.029698
# 4   R  0.028502
# 3   L  0.021936

# %% [markdown]
# Curious how long most players that make the HoF have played in the NHL

# %%
hof_df = master_df[master_df["isInHf"] == 1].sort_values(by='nhlLength', ascending=True)
print(hof_df.describe())
hof_df.head(25)
# Out:
#            height      weight     firstNHL      lastNHL   nhlLength  isInHf  \
# count  214.000000  214.000000   214.000000   214.000000  214.000000   214.0
# mean    70.845794  181.677570  1947.252336  1960.406542   14.154206     1.0
# std      2.183927   17.823173    22.123042    25.722575    5.835745     0.0
# min     63.000000  135.000000  1917.000000  1917.000000    1.000000     1.0
# 25%     70.000000  170.000000  1926.000000  1937.000000   11.000000     1.0
# 50%     71.000000  181.000000  1944.000000  1956.000000   14.500000     1.0
# 75%     72.000000  192.750000  1968.000000  1981.750000   18.000000     1.0
# max     76.000000  230.000000  1989.000000  2006.000000   34.000000     1.0
#
#        awardCount
# count  214.000000
# mean     5.042056
# std      6.426406
# min      0.000000
# 25%      0.000000
# 50%      4.000000
# 75%      6.750000
# max     51.000000
#        playerID birthCountry       hofID firstName     lastName  height  \
# 3317  lavioja01       Canada  lavioja01h      Jack   Laviolette    71.0
# 5603  smithto01       Canada  smithto01h     Tommy        Smith    66.0
# 5693  stanlba01       Canada  stanlba01h    Barney      Stanley    72.0
# 5147   rossar01       Canada   rossar01h       Art         Ross    71.0
# 2646  hylanha01       Canada  hylanha01h     Harry       Hyland    66.0
# 3377  lehmahu01       Canada  lehmahu01h      Hugh       Lehman    68.0
# 1825  foystfr01       Canada  foystfr01h     Frank      Foyston    69.0
# 55    allenke01       Canada  allenke01h     Keith        Allen    71.0
# 2226   halljo01      England   halljo01h       Joe         Hall    70.0
# 4601  patrile01       Canada  patrile01h    Lester      Patrick    73.0
# 6241  walkeja01       Canada  walkeja01h      Jack       Walker    68.0
# 1193  crawfru01       Canada  crawfru01h     Rusty     Crawford    71.0
# 2673  irvindi01       Canada  irvindi01h      Dick        Irvin    69.0
# 1913  gardihe01       Canada  gardihe01h      Herb     Gardiner    70.0
# 2914  keatsdu01       Canada  keatsdu01h      Duke        Keats    71.0
# 3793  mathefr01       Canada  mathefr01h     Frank      Mathers    73.0
# 2132  greensh01       Canada  greensh01h    Shorty        Green    70.0
# 3611  mackami01       Canada  mackami01h    Mickey       MacKay    69.0
# 1139  costemu01       Canada  costemu01h    Murray     Costello    75.0
# 1847  fredrfr01       Canada  fredrfr01h     Frank  Fredrickson    71.0
# 834   camerha01       Canada  camerha01h     Harry      Cameron    70.0
# 1828  francem01       Canada  francem01h     Emile      Francis    66.0
# 1964  gerared01       Canada  gerared01h     Eddie       Gerard    69.0
# 5498  simpsjo01       Canada  simpsjo01h       Joe      Simpson    70.0
# 4738  pitredi01       Canada  pitredi01h    Didier        Pitre    71.0
#
#       weight shootCatch  firstNHL  lastNHL pos  nhlLength  isInHf  \
# 3317   170.0          R    1917.0   1917.0   D        1.0       1
# 5603   150.0          L    1919.0   1919.0   C        1.0       1
# 5693   175.0          L    1927.0   1927.0   R        1.0       1
# 5147   190.0          L    1917.0   1917.0   D        1.0       1
# 2646   156.0          R    1917.0   1917.0   R        1.0       1
# 3377   168.0          L    1926.0   1927.0   G        2.0       1
# 1825   158.0          L    1926.0   1927.0   C        2.0       1
# 55     190.0          L    1953.0   1954.0   D        2.0       1
# 2226   175.0          R    1917.0   1918.0   D        2.0       1
# 4601   180.0          R    1926.0   1927.0   D        2.0       1
# 6241   153.0          L    1926.0   1927.0   C        2.0       1
# 1193   165.0          L    1917.0   1918.0   L        2.0       1
# 2673   162.0          R    1926.0   1928.0   C        3.0       1
# 1913   190.0          L    1926.0   1928.0   D        3.0       1
# 2914   195.0          R    1926.0   1928.0   C        3.0       1
# 3793   182.0          L    1948.0   1951.0   D        4.0       1
# 2132   152.0          R    1923.0   1926.0   R        4.0       1
# 3611   162.0          L    1926.0   1929.0   C        4.0       1
# 1139   190.0          R    1953.0   1956.0   C        4.0       1
# 1847   180.0          L    1926.0   1930.0   C        5.0       1
# 834    155.0          R    1917.0   1922.0   D        6.0       1
# 1828   145.0          L    1946.0   1951.0   G        6.0       1
# 1964   168.0          L    1917.0   1922.0   D        6.0       1
# 5498   175.0          R    1925.0   1930.0   D        6.0       1
# 4738   185.0          R    1917.0   1922.0   R        6.0       1
#
#                fullName  awardCount
# 3317    Jack Laviolette         0.0
# 5603        Tommy Smith         0.0
# 5693     Barney Stanley         0.0
# 5147           Art Ross         0.0
# 2646       Harry Hyland         0.0
# 3377        Hugh Lehman         0.0
# 1825      Frank Foyston         0.0
# 55          Keith Allen         0.0
# 2226           Joe Hall         0.0
# 4601     Lester Patrick         0.0
# 6241        Jack Walker         0.0
# 1193     Rusty Crawford         0.0
# 2673         Dick Irvin         0.0
# 1913      Herb Gardiner         1.0
# 2914         Duke Keats         0.0
# 3793      Frank Mathers         0.0
# 2132       Shorty Green         0.0
# 3611      Mickey MacKay         0.0
# 1139    Murray Costello         0.0
# 1847  Frank Fredrickson         0.0
# 834       Harry Cameron         0.0
# 1828      Emile Francis         0.0
# 1964       Eddie Gerard         0.0
# 5498        Joe Simpson         0.0
# 4738       Didier Pitre         0.0

# %% [markdown]
# Looks like in the beginning of the NHL, you didn't have to play for too long, but over time the average went up to around 14-15 years.

# %% [markdown]
# ## Visualize the Data ##

# %%
def plot_distribution( df, var, target, **kwargs):
    row = kwargs.get('row', None)
    col = kwargs.get('col', None)
    facet = sns.FacetGrid(df , hue=target, aspect=3, row=row, col=col)
    facet.map(sns.kdeplot, var, shade=True)
    facet.set(xlim=(df[var].min() , df[var].max()))
    facet.add_legend()

def plot_categories(df, cat, target, **kwargs):
    row = kwargs.get('row', None)
    col = kwargs.get('col', None)
    facet = sns.FacetGrid(df, row=row, col=col)
    facet.map(sns.barplot, cat, target)
    facet.add_legend()

categories_to_plot = ['shootCatch', 'pos']
for category in categories_to_plot:
	plot_categories(master_df, category, 'isInHf')

features_to_plot = ['height', 'weight', 'awardCount', 'nhlLength']
for feature in features_to_plot:
	plot_distribution(master_df, feature, 'isInHf')

# %% [markdown]
# ## Prepare features for classification algorithms

# %% [markdown]
# We'll convert country strings to integers

# %%
countryIx = 0
countryMap = {}

def convertCountryMap(country):
    global countryIx, countryMap
    if country in countryMap.keys():
        return countryMap[country]
    else:
        countryMap[country] = countryIx
        countryIx += 1
        return countryMap[country]
    
master_df['birthCountry'] = master_df.birthCountry.apply(convertCountryMap)
print(countryMap)
master_df.head(25)
# Out:
# {'Finland': 0, 'Canada': 1, 'USA': 2, 'Sweden': 3, 'Brunei Darussalam': 4, 'Switzerland': 5, 'Russia': 6, 'Scotland': 7, 'Belarus': 8, 'Latvia': 9, 'Czech Republic': 10, 'Ukraine': 11, 'Slovakia': 12, 'England': 13, 'Belgium': 14, 'Croatia': 15, 'Denmark': 16, 'Yugoslavia': 17, 'USSR': 18, 'France': 19, 'Austria': 20, 'Germany': 21, 'Venezuela': 22, 'Wales': 23, 'Poland': 24, 'Italy': 25, 'South Wales': 26, 'Ireland': 27, 'Japan': 28, 'Brazil': 29, 'Lebanon': 30, 'Lithuania': 31, 'Netherlands': 32, 'Kazakhstan': 33, 'Norway': 34, 'South Africa': 35, 'Slovenia': 36, 'Taiwan': 37, 'Nigeria': 38, 'Tanzania': 39, 'Korea': 40, 'South Korea': 41, 'Paraguay': 42, 'Indonesia': 43, 'Jamaica': 44, 'Haiti': 45}
#      playerID  birthCountry       hofID firstName     lastName  height  \
# 0   aaltoan01             0         NaN     Antti        Aalto    73.0
# 1   abbotge01             1         NaN    George       Abbott    67.0
# 2   abbotre01             1         NaN       Reg       Abbott    71.0
# 3   abdelju01             2         NaN    Justin   Abdelkader    73.0
# 4    abelcl01             2         NaN  Clarence         Abel    73.0
# 5    abelge01             2         NaN     Gerry         Abel    74.0
# 6    abelsi01             1   abelsi01h       Sid         Abel    71.0
# 7   abgrade01             1         NaN    Dennis      Abgrall    73.0
# 8    abidra01             1         NaN     Ramzi         Abid    74.0
# 9   abrahth01             3         NaN    Thommy  Abrahamsson    74.0
# 10  achtyge01             1         NaN      Gene  Achtymichuk    71.0
# 11  acombdo01             1         NaN      Doug        Acomb    71.0
# 12  actonke01             1         NaN     Keith        Acton    68.0
# 13   adamdo01             1         NaN   Douglas         Adam    71.0
# 14   adamru01             1         NaN      Russ         Adam    70.0
# 15  adamsbr01             1         NaN     Bryan        Adams    72.0
# 16  adamscr01             4         NaN     Craig        Adams    72.0
# 17  adamsgr01             1         NaN      Greg        Adams    73.0
# 18  adamsgr02             1         NaN      Greg        Adams    75.0
# 19  adamsja01             1  adamsja01h      Jack        Adams    69.0
# 20  adamsjo01             1         NaN      John        Adams    70.0
# 21  adamsjo02             1         NaN      John        Adams    72.0
# 22  adamske01             2         NaN     Kevyn        Adams    73.0
# 23  adamsst01             1         NaN      Stew        Adams    70.0
# 24  adduori01             1         NaN      Rick      Adduono    71.0
#
#     weight shootCatch  firstNHL  lastNHL pos  nhlLength  isInHf  \
# 0    210.0          L    1997.0   2000.0   C        4.0       0
# 1    153.0          L    1943.0   1943.0   G        1.0       0
# 2    164.0          L    1952.0   1952.0   C        1.0       0
# 3    195.0          L    2007.0   2011.0   L        5.0       0
# 4    225.0          L    1926.0   1933.0   D        8.0       0
# 5    168.0          L    1966.0   1966.0   L        1.0       0
# 6    170.0          L    1938.0   1953.0   C       16.0       1
# 7    180.0          R    1975.0   1975.0   R        1.0       0
# 8    210.0          L    2002.0   2006.0   L        5.0       0
# 9    185.0          L    1980.0   1980.0   D        1.0       0
# 10   170.0          L    1951.0   1958.0   C        8.0       0
# 11   165.0          L    1969.0   1969.0   C        1.0       0
# 12   170.0          L    1979.0   1993.0   C       15.0       0
# 13   165.0          L    1949.0   1949.0   L        1.0       0
# 14   185.0          L    1982.0   1982.0   C        1.0       0
# 15   185.0          L    1999.0   2000.0   L        2.0       0
# 16   200.0          R    2000.0   2011.0   R       12.0       0
# 17   190.0          L    1980.0   1989.0   L       10.0       0
# 18   195.0          L    1984.0   2000.0   L       17.0       0
# 19   175.0          R    1917.0   1926.0   C       10.0       1
# 20   163.0          L    1940.0   1940.0   L        1.0       0
# 21   200.0          L    1972.0   1974.0   G        3.0       0
# 22   200.0          R    1997.0   2007.0   C       11.0       0
# 23   165.0          L    1929.0   1932.0   L        4.0       0
# 24   182.0          L    1975.0   1979.0   C        5.0       0
#
#               fullName  awardCount
# 0          Antti Aalto         0.0
# 1        George Abbott         0.0
# 2           Reg Abbott         0.0
# 3    Justin Abdelkader         0.0
# 4        Clarence Abel         0.0
# 5           Gerry Abel         0.0
# 6             Sid Abel         5.0
# 7       Dennis Abgrall         0.0
# 8           Ramzi Abid         0.0
# 9   Thommy Abrahamsson         0.0
# 10    Gene Achtymichuk         0.0
# 11          Doug Acomb         0.0
# 12         Keith Acton         0.0
# 13        Douglas Adam         0.0
# 14           Russ Adam         0.0
# 15         Bryan Adams         0.0
# 16         Craig Adams         0.0
# 17          Greg Adams         0.0
# 18          Greg Adams         0.0
# 19          Jack Adams         0.0
# 20          John Adams         0.0
# 21          John Adams         0.0
# 22         Kevyn Adams         0.0
# 23          Stew Adams         0.0
# 24        Rick Adduono         0.0

# %% [markdown]
# Do the same with shootCatch and pos

# %%
master_df["shootCatch"] = master_df['shootCatch'].map( {'L': 1, 'R': 0} )
master_df["pos"] = master_df['pos'].map( {'C': 0, 'F': 1, 'D': 2, 'G': 3, 'L': 4, 'R': 5} )
master_df.head(25)
# Out:
#      playerID  birthCountry       hofID firstName     lastName  height  \
# 0   aaltoan01             0         NaN     Antti        Aalto    73.0
# 1   abbotge01             1         NaN    George       Abbott    67.0
# 2   abbotre01             1         NaN       Reg       Abbott    71.0
# 3   abdelju01             2         NaN    Justin   Abdelkader    73.0
# 4    abelcl01             2         NaN  Clarence         Abel    73.0
# 5    abelge01             2         NaN     Gerry         Abel    74.0
# 6    abelsi01             1   abelsi01h       Sid         Abel    71.0
# 7   abgrade01             1         NaN    Dennis      Abgrall    73.0
# 8    abidra01             1         NaN     Ramzi         Abid    74.0
# 9   abrahth01             3         NaN    Thommy  Abrahamsson    74.0
# 10  achtyge01             1         NaN      Gene  Achtymichuk    71.0
# 11  acombdo01             1         NaN      Doug        Acomb    71.0
# 12  actonke01             1         NaN     Keith        Acton    68.0
# 13   adamdo01             1         NaN   Douglas         Adam    71.0
# 14   adamru01             1         NaN      Russ         Adam    70.0
# 15  adamsbr01             1         NaN     Bryan        Adams    72.0
# 16  adamscr01             4         NaN     Craig        Adams    72.0
# 17  adamsgr01             1         NaN      Greg        Adams    73.0
# 18  adamsgr02             1         NaN      Greg        Adams    75.0
# 19  adamsja01             1  adamsja01h      Jack        Adams    69.0
# 20  adamsjo01             1         NaN      John        Adams    70.0
# 21  adamsjo02             1         NaN      John        Adams    72.0
# 22  adamske01             2         NaN     Kevyn        Adams    73.0
# 23  adamsst01             1         NaN      Stew        Adams    70.0
# 24  adduori01             1         NaN      Rick      Adduono    71.0
#
#     weight  shootCatch  firstNHL  lastNHL  pos  nhlLength  isInHf  \
# 0    210.0           1    1997.0   2000.0    0        4.0       0
# 1    153.0           1    1943.0   1943.0    3        1.0       0
# 2    164.0           1    1952.0   1952.0    0        1.0       0
# 3    195.0           1    2007.0   2011.0    4        5.0       0
# 4    225.0           1    1926.0   1933.0    2        8.0       0
# 5    168.0           1    1966.0   1966.0    4        1.0       0
# 6    170.0           1    1938.0   1953.0    0       16.0       1
# 7    180.0           0    1975.0   1975.0    5        1.0       0
# 8    210.0           1    2002.0   2006.0    4        5.0       0
# 9    185.0           1    1980.0   1980.0    2        1.0       0
# 10   170.0           1    1951.0   1958.0    0        8.0       0
# 11   165.0           1    1969.0   1969.0    0        1.0       0
# 12   170.0           1    1979.0   1993.0    0       15.0       0
# 13   165.0           1    1949.0   1949.0    4        1.0       0
# 14   185.0           1    1982.0   1982.0    0        1.0       0
# 15   185.0           1    1999.0   2000.0    4        2.0       0
# 16   200.0           0    2000.0   2011.0    5       12.0       0
# 17   190.0           1    1980.0   1989.0    4       10.0       0
# 18   195.0           1    1984.0   2000.0    4       17.0       0
# 19   175.0           0    1917.0   1926.0    0       10.0       1
# 20   163.0           1    1940.0   1940.0    4        1.0       0
# 21   200.0           1    1972.0   1974.0    3        3.0       0
# 22   200.0           0    1997.0   2007.0    0       11.0       0
# 23   165.0           1    1929.0   1932.0    4        4.0       0
# 24   182.0           1    1975.0   1979.0    0        5.0       0
#
#               fullName  awardCount
# 0          Antti Aalto         0.0
# 1        George Abbott         0.0
# 2           Reg Abbott         0.0
# 3    Justin Abdelkader         0.0
# 4        Clarence Abel         0.0
# 5           Gerry Abel         0.0
# 6             Sid Abel         5.0
# 7       Dennis Abgrall         0.0
# 8           Ramzi Abid         0.0
# 9   Thommy Abrahamsson         0.0
# 10    Gene Achtymichuk         0.0
# 11          Doug Acomb         0.0
# 12         Keith Acton         0.0
# 13        Douglas Adam         0.0
# 14           Russ Adam         0.0
# 15         Bryan Adams         0.0
# 16         Craig Adams         0.0
# 17          Greg Adams         0.0
# 18          Greg Adams         0.0
# 19          Jack Adams         0.0
# 20          John Adams         0.0
# 21          John Adams         0.0
# 22         Kevyn Adams         0.0
# 23          Stew Adams         0.0
# 24        Rick Adduono         0.0

# %%
master_df[master_df["isInHf"] == 1].sort_values(by='nhlLength', ascending=True).head(15)
# Out:
#        playerID  birthCountry       hofID firstName    lastName  height  \
# 3317  lavioja01             1  lavioja01h      Jack  Laviolette    71.0
# 5603  smithto01             1  smithto01h     Tommy       Smith    66.0
# 5693  stanlba01             1  stanlba01h    Barney     Stanley    72.0
# 5147   rossar01             1   rossar01h       Art        Ross    71.0
# 2646  hylanha01             1  hylanha01h     Harry      Hyland    66.0
# 3377  lehmahu01             1  lehmahu01h      Hugh      Lehman    68.0
# 1825  foystfr01             1  foystfr01h     Frank     Foyston    69.0
# 55    allenke01             1  allenke01h     Keith       Allen    71.0
# 2226   halljo01            13   halljo01h       Joe        Hall    70.0
# 4601  patrile01             1  patrile01h    Lester     Patrick    73.0
# 6241  walkeja01             1  walkeja01h      Jack      Walker    68.0
# 1193  crawfru01             1  crawfru01h     Rusty    Crawford    71.0
# 2673  irvindi01             1  irvindi01h      Dick       Irvin    69.0
# 1913  gardihe01             1  gardihe01h      Herb    Gardiner    70.0
# 2914  keatsdu01             1  keatsdu01h      Duke       Keats    71.0
#
#       weight  shootCatch  firstNHL  lastNHL  pos  nhlLength  isInHf  \
# 3317   170.0           0    1917.0   1917.0    2        1.0       1
# 5603   150.0           1    1919.0   1919.0    0        1.0       1
# 5693   175.0           1    1927.0   1927.0    5        1.0       1
# 5147   190.0           1    1917.0   1917.0    2        1.0       1
# 2646   156.0           0    1917.0   1917.0    5        1.0       1
# 3377   168.0           1    1926.0   1927.0    3        2.0       1
# 1825   158.0           1    1926.0   1927.0    0        2.0       1
# 55     190.0           1    1953.0   1954.0    2        2.0       1
# 2226   175.0           0    1917.0   1918.0    2        2.0       1
# 4601   180.0           0    1926.0   1927.0    2        2.0       1
# 6241   153.0           1    1926.0   1927.0    0        2.0       1
# 1193   165.0           1    1917.0   1918.0    4        2.0       1
# 2673   162.0           0    1926.0   1928.0    0        3.0       1
# 1913   190.0           1    1926.0   1928.0    2        3.0       1
# 2914   195.0           0    1926.0   1928.0    0        3.0       1
#
#              fullName  awardCount
# 3317  Jack Laviolette         0.0
# 5603      Tommy Smith         0.0
# 5693   Barney Stanley         0.0
# 5147         Art Ross         0.0
# 2646     Harry Hyland         0.0
# 3377      Hugh Lehman         0.0
# 1825    Frank Foyston         0.0
# 55        Keith Allen         0.0
# 2226         Joe Hall         0.0
# 4601   Lester Patrick         0.0
# 6241      Jack Walker         0.0
# 1193   Rusty Crawford         0.0
# 2673       Dick Irvin         0.0
# 1913    Herb Gardiner         1.0
# 2914       Duke Keats         0.0

# %% [markdown]
# ### Update HoF Data since 2011
# I went and looked up who made the HoF since 2011 and listed their playerIds so I can use this data to test whether or not my models could predict these players, and then I can filter them out later to see who the next players might be.

# %%
new_hof = ['burepa01',
'oatesad01',
'sakicjo01',
'sundima01',
'chelich01',
'niedesc01',
'shanabr01',
'hasekdo01',
'forsbpe01',
'modanmi01',
'blakero01',
'lidstni01',
'fedorse01',
'houslph01',
'prongch01',
'lindrer01',
'vachoro01',
'makarse01'
]

new_hof_players_df = master_df[master_df['playerID'].isin(new_hof)]
print(new_hof_players_df.shape)

#for playerId in new_hof:
    #master_df.loc[master_df['playerID'] == playerId, 'isInHf'] = 1
# Out:
# (18, 15)

# %% [markdown]
# ## Split our Dataset ##
# Here is where things get creative. Since there is no real cutoff for getting into the HoF, it's hard to know if a player still has no chance at making it, so we'll create some thresholds for grouping our data for training/testing purposes.
#
# Also since current players can't make the HoF, we'll need to exclude them as well.

# %%
season_threshold = 2000

# We're saying that a player is eligible for the HoF if they haven't been selected
# and they retired at some point since our threshold (2000) and that they aren't currently
# playing, ( lastNHL == 2011 )
# NOTE: Since this was 6 years ago, there is an obvious gap in player retirements that we'll miss in predictions
eligible_players = master_df[(master_df['isInHf'] == 0) & (master_df['lastNHL'] >= season_threshold) & (master_df['lastNHL'] < 2011)]
print(eligible_players.shape)

# Players that have a low chance of being inducted if they haven't already
retired_players = master_df[master_df['lastNHL'] < season_threshold]
print(retired_players.shape)
# Out:
# (1512, 15)
# (4288, 15)

# %%
retired_players.head()
# Out:
#     playerID  birthCountry      hofID firstName lastName  height  weight  \
# 1  abbotge01             1        NaN    George   Abbott    67.0   153.0
# 2  abbotre01             1        NaN       Reg   Abbott    71.0   164.0
# 4   abelcl01             2        NaN  Clarence     Abel    73.0   225.0
# 5   abelge01             2        NaN     Gerry     Abel    74.0   168.0
# 6   abelsi01             1  abelsi01h       Sid     Abel    71.0   170.0
#
#    shootCatch  firstNHL  lastNHL  pos  nhlLength  isInHf       fullName  \
# 1           1    1943.0   1943.0    3        1.0       0  George Abbott
# 2           1    1952.0   1952.0    0        1.0       0     Reg Abbott
# 4           1    1926.0   1933.0    2        8.0       0  Clarence Abel
# 5           1    1966.0   1966.0    4        1.0       0     Gerry Abel
# 6           1    1938.0   1953.0    0       16.0       1       Sid Abel
#
#    awardCount
# 1         0.0
# 2         0.0
# 4         0.0
# 5         0.0
# 6         5.0

# %% [markdown]
# Now with the data prepared, let's cut out the last of the columns we don't want to feed into the classification training.

# %%
cols = ['playerID', 'fullName', 'birthCountry', 'height', 'weight', 'shootCatch', 'nhlLength', 'pos', 'isInHf', 'awardCount']
retired_players = retired_players[cols]
eligible_players = eligible_players[cols]
new_hof_players_df = new_hof_players_df[cols]
eligible_players.head()
# Out:
#      playerID     fullName  birthCountry  height  weight  shootCatch  \
# 0   aaltoan01  Antti Aalto             0    73.0   210.0           1
# 8    abidra01   Ramzi Abid             1    74.0   210.0           1
# 15  adamsbr01  Bryan Adams             1    72.0   185.0           1
# 18  adamsgr02   Greg Adams             1    75.0   195.0           1
# 22  adamske01  Kevyn Adams             2    73.0   200.0           0
#
#     nhlLength  pos  isInHf  awardCount
# 0         4.0    0       0         0.0
# 8         5.0    4       0         0.0
# 15        2.0    4       0         0.0
# 18       17.0    4       0         0.0
# 22       11.0    0       0         0.0

# %% [markdown]
# Before we predict, let's look at some correlating features

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 240 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )
    
plot_correlation_map( retired_players )

# %%
cols_to_drop = ['playerID', 'fullName', 'isInHf']

# Break the dataset into a training and cross validation set
train=retired_players.sample(frac=0.75,random_state=200)
test=retired_players.drop(train.index)

X_train = train.drop(cols_to_drop, axis=1)
Y_train = train['isInHf']
X_test = test.drop(cols_to_drop, axis=1).copy()
Y_test = test['isInHf']

# Dataset with unknown HoF predictions
X_player_test = eligible_players.drop(cols_to_drop, axis=1).copy()

# Create a test set of players that have made the HF since the last year of available data in this data set
# We'll just fill the Y with 1's
X_new_hof_test = new_hof_players_df.drop(cols_to_drop, axis=1).copy()
Y_new_hof_test = np.ones(X_new_hof_test.shape[0], dtype=np.int)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((3216, 7), (3216,), (1072, 7), (1072,))

# %% [markdown]
# Below are some common functions we are going to reuse against all the different classification alogrithms

# %%
classifiers = {}
# Run a classifier instance against the training set
def run_classifier(classifier):
    # Get the name of the classifier instance
    class_name = classifier.__class__.__name__
    print("Testing {0}".format(class_name))
    print("----------------------------------------\n")
    
    # Fit the classifier to the training set
    classifier.fit(X_train, Y_train)
    # Find out the training accuracy
    training_accuracy = round(classifier.score(X_train, Y_train) * 100, 2)
    print("Training Score: {0}".format(training_accuracy))
    
    # Use the trained data to predict the next HoF's
    Y_pred = classifier.predict(X_test)
    
    # How accurate was it against the known set of recent HoF's
    hof_accuracy = test_current_hf(classifier)
    
    # Cross validation scores
    f1_score = f1(Y_test, Y_pred)
    
    
    print("\n----- Predictions -----\n")
    # For all the classifiers except LinearSVC, we'll determine the probability in addition
    # to the prediction
    if class_name != 'LinearSVC':
        (positive_predictions, _) = show_prediction_with_probabilities(classifier, X_player_test)
    else:
        (positive_predictions, _) = show_prediction(classifier, X_player_test)
        
    # Store our results per classifier for later analysis    
    classifiers[class_name] = {
        'Training Accuracy': training_accuracy,
        'F1 Score': f1_score,
        'Current HoF Accuracy': hof_accuracy
    }
    return positive_predictions

# Given our set of known recent HoF additions, does the classifier think they should have made it?
def test_current_hf(classifier):
    accuracy = round(classifier.score(X_new_hof_test, Y_new_hof_test) * 100, 2)
    print("Accuracy with Current HF: {0}".format(accuracy))
    return accuracy

# Display from cross validation scores, F1, precision, recall
def f1(Y_test, Y_pred):
    macro = f1_score(Y_test.values, Y_pred, average='macro')
    print("F1 Score: {0}".format(formatPercent(macro)))
    precision = precision_score(Y_test.values, Y_pred, average='macro')
    print("Precision Score: {0}".format(formatPercent(precision)))
    recall = recall_score(Y_test.values, Y_pred, average='macro')
    print("Recall Score: {0}".format(formatPercent(recall)))
    return macro

def formatPercent(num):
    return round(num, 2)
    
def show_prediction_with_probabilities(classifier, X_player_test, display=True):
    prediction = classifier.predict(X_player_test)
    prob = classifier.predict_proba(X_player_test)
    pred_df = pd.DataFrame({
        "playerID": eligible_players["playerID"],
        "fullName": eligible_players["fullName"],
        "isInHfPrediction": prediction,
        #"prob1": prob[:,0],
        "probability": prob[:,1]
    })
    positive_predictions = pred_df[pred_df['isInHfPrediction'] == 1]
    if display == True:
        print(positive_predictions.sort_values(by='probability', ascending=False))    
    return positive_predictions, pred_df

def show_prediction(classifier, X_player_test):
    prediction = classifier.predict(X_player_test)
    pred_df = pd.DataFrame({
        "playerID": eligible_players["playerID"],
        "fullName": eligible_players["fullName"],
        "isInHfPrediction": prediction
    })
    positive_predictions = pred_df[pred_df['isInHfPrediction'] == 1]
    print(positive_predictions)
    return positive_predictions, pred_df

# %%
nn = MLPClassifier(alpha=1)
nn_pred = run_classifier(nn)
# Out:
# Testing MLPClassifier
# ----------------------------------------
#
# Training Score: 97.23
# Accuracy with Current HF: 66.67
# F1 Score: 0.75
# Precision Score: 0.94
# Recall Score: 0.68
#
# ----- Predictions -----
#
#                 fullName  isInHfPrediction   playerID  probability
# 2315       Dominik Hasek                 1  hasekdo01     0.999990
# 955        Chris Chelios                 1  chelich01     0.999790
# 5229           Joe Sakic                 1  sakicjo01     0.981672
# 2890         Paul Kariya                 1  kariypa01     0.959242
# 1800      Peter Forsberg                 1  forsbpe01     0.947332
# 4367   Scott Niedermayer                 1  niedesc01     0.930656
# 248         Tom Barrasso                 1  barrato01     0.916740
# 1692      Sergei Fedorov                 1  fedorse01     0.871240
# 465            Rob Blake                 1  blakero01     0.832836
# 3348        John LeClair                 1  leclajo01     0.804932
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.710213
# 755           Pavel Bure                 1   burepa01     0.647605
# 6180         Mike Vernon                 1  vernomi01     0.637327
# 650      Rod Brind'Amour                 1  brindro01     0.619292
# 5411    Brendan Shanahan                 1  shanabr01     0.615801
# 4515        Chris Osgood                 1  osgooch01     0.540809
# 2565        Phil Housley                 1  houslph01     0.503255
# 3046         Olaf Kolzig                 1  kolziol01     0.501048

# %%
logreg = LogisticRegression()
logreg_pred = run_classifier(logreg)
# Out:
# Testing LogisticRegression
# ----------------------------------------
#
# Training Score: 97.39
# Accuracy with Current HF: 66.67
# F1 Score: 0.77
# Precision Score: 0.96
# Recall Score: 0.7
#
# ----- Predictions -----
#
#                 fullName  isInHfPrediction   playerID  probability
# 2315       Dominik Hasek                 1  hasekdo01     0.999999
# 955        Chris Chelios                 1  chelich01     0.999950
# 5229           Joe Sakic                 1  sakicjo01     0.990800
# 1800      Peter Forsberg                 1  forsbpe01     0.976015
# 2890         Paul Kariya                 1  kariypa01     0.974604
# 248         Tom Barrasso                 1  barrato01     0.957850
# 4367   Scott Niedermayer                 1  niedesc01     0.955564
# 1692      Sergei Fedorov                 1  fedorse01     0.926088
# 465            Rob Blake                 1  blakero01     0.904080
# 3348        John LeClair                 1  leclajo01     0.852859
# 755           Pavel Bure                 1   burepa01     0.716279
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.681158
# 5411    Brendan Shanahan                 1  shanabr01     0.662681
# 650      Rod Brind'Amour                 1  brindro01     0.641168
# 6180         Mike Vernon                 1  vernomi01     0.607612
# 3472        Eric Lindros                 1  lindrer01     0.552018
# 3046         Olaf Kolzig                 1  kolziol01     0.532427
# 4515        Chris Osgood                 1  osgooch01     0.524728

# %%
svc = SVC(probability=True)
svc_pred = run_classifier(svc)
# Out:
# Testing SVC
# ----------------------------------------
#
# Training Score: 98.32
# Accuracy with Current HF: 0.0
# F1 Score: 0.5
# Precision Score: 0.97
# Recall Score: 0.51
#
# ----- Predictions -----
#
#           fullName  isInHfPrediction   playerID  probability
# 4515  Chris Osgood                 1  osgooch01     0.973443

# %%
coeff_df = pd.DataFrame(retired_players.columns.drop(['playerID', 'fullName', 'isInHf']))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#         Feature  Correlation
# 6    awardCount     0.803991
# 4     nhlLength     0.189768
# 0  birthCountry     0.022782
# 1        height    -0.008926
# 2        weight    -0.025083
# 5           pos    -0.142135
# 3    shootCatch    -0.253479

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn_pred = run_classifier(knn)
# Out:
# Testing KNeighborsClassifier
# ----------------------------------------
#
# Training Score: 97.54
# Accuracy with Current HF: 44.44
# F1 Score: 0.68
# Precision Score: 0.92
# Recall Score: 0.62
#
# ----- Predictions -----
#
#                 fullName  isInHfPrediction   playerID  probability
# 5229           Joe Sakic                 1  sakicjo01     1.000000
# 1800      Peter Forsberg                 1  forsbpe01     1.000000
# 2315       Dominik Hasek                 1  hasekdo01     1.000000
# 2890         Paul Kariya                 1  kariypa01     1.000000
# 955        Chris Chelios                 1  chelich01     1.000000
# 4515        Chris Osgood                 1  osgooch01     1.000000
# 755           Pavel Bure                 1   burepa01     0.666667
# 4367   Scott Niedermayer                 1  niedesc01     0.666667
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.666667
# 5138       Cliff Ronning                 1  ronnicl01     0.666667
# 3087   Vyacheslav Kozlov                 1  kozlovy01     0.666667
# 4314      Markus Naslund                 1  nasluma02     0.666667
# 3830       Dean McAmmond                 1  mcammde01     0.666667
# 2835       Curtis Joseph                 1  josepcu01     0.666667
# 1772      Theoren Fleury                 1  fleurth01     0.666667
# 1692      Sergei Fedorov                 1  fedorse01     0.666667
# 6180         Mike Vernon                 1  vernomi01     0.666667

# %%
gaussian = GaussianNB()
gaussian_pred = run_classifier(gaussian)
# Out:
# Testing GaussianNB
# ----------------------------------------
#
# Training Score: 95.93
# Accuracy with Current HF: 94.44
# F1 Score: 0.8
# Precision Score: 0.8
# Recall Score: 0.8
#
# ----- Predictions -----
#
#                     fullName  isInHfPrediction   playerID  probability
# 248             Tom Barrasso                 1  barrato01     1.000000
# 5229               Joe Sakic                 1  sakicjo01     1.000000
# 2890             Paul Kariya                 1  kariypa01     1.000000
# 3472            Eric Lindros                 1  lindrer01     1.000000
# 2315           Dominik Hasek                 1  hasekdo01     1.000000
# 4367       Scott Niedermayer                 1  niedesc01     1.000000
# 1800          Peter Forsberg                 1  forsbpe01     1.000000
# 1692          Sergei Fedorov                 1  fedorse01     1.000000
# 955            Chris Chelios                 1  chelich01     1.000000
# 755               Pavel Bure                 1   burepa01     1.000000
# 465                Rob Blake                 1  blakero01     1.000000
# 3348            John LeClair                 1  leclajo01     1.000000
# 3046             Olaf Kolzig                 1  kolziol01     1.000000
# 5411        Brendan Shanahan                 1  shanabr01     1.000000
# 4314          Markus Naslund                 1  nasluma02     1.000000
# 6139      John Vanbiesbrouck                 1  vanbijo01     1.000000
# 650          Rod Brind'Amour                 1  brindro01     1.000000
# 6180             Mike Vernon                 1  vernomi01     1.000000
# 4976           Richie Regehr                 1  regehri01     0.999999
# 4515            Chris Osgood                 1  osgooch01     0.999999
# 5843              Gary Suter                 1  suterga01     0.999997
# 4150       Alexander Mogilny                 1  mogilal01     0.999997
# 5834             Mats Sundin                 1  sundima01     0.999997
# 2113             Adam Graves                 1  gravead01     0.999994
# 3381           Jere Lehtinen                 1  lehtije01     0.999990
# 5739           Kevin Stevens                 1  steveke01     0.999980
# 365             Bryan Berard                 1  berarbr01     0.999961
# 4369           Chris Nielsen                 1  nielsch01     0.999948
# 6092             Roman Turek                 1  turekro01     0.999883
# 3025           Espen Knutsen                 1  knutses01     0.999446
# 2901      Darius Kasparaitis                 1  kaspada01     0.999249
# 4301          Anders Myrvold                 1  myrvoan01     0.999174
# 4141             Mike Modano                 1  modanmi01     0.998051
# 2565            Phil Housley                 1  houslph01     0.997585
# 6021  Ole-Kristian Tollefsen                 1  tolleol01     0.996717
# 4399              Owen Nolan                 1  nolanow01     0.996352
# 5983        Patrick Thoresen                 1  thorepa01     0.996008
# 6495        Vitali Yeremeyev                 1  yeremvi01     0.993585
# 4882    Konstantin Pushkarev                 1  pushkko01     0.989362
# 4609         Dimitri Patzold                 1  patzodi01     0.988093
# 6222          Pavel Vorobiev                 1  vorobpa01     0.986246
# 4659    Alexander Perezhogin                 1  perezal01     0.984616
# 3464           Trevor Linden                 1  lindetr01     0.984364
# 3042         Vitaly Kolesnik                 1  kolesvi01     0.979829
# 6010           Keith Tkachuk                 1  tkachke01     0.972664
# 1374         Eric Desjardins                 1  desjaer01     0.971048
# 4628            Michael Peca                 1   pecami01     0.970754
# 1772          Theoren Fleury                 1  fleurth01     0.957455
# 5246         Sergei Samsonov                 1  samsose01     0.937173
# 1714         Manny Fernandez                 1  fernama01     0.919450
# 1486             Chris Drury                 1  drurych01     0.903390
# 2101            Tony Granato                 1  granato01     0.852230
# 3400          Claude Lemieux                 1  lemiecl01     0.843779
# 4957             Mark Recchi                 1  recchma01     0.756262
# 1469             Kris Draper                 1  drapekr01     0.707594
# 1255      Mariusz Czerkawski                 1  czerkma01     0.705619
# 6312             Doug Weight                 1  weighdo01     0.647407
# 1870         Yutaka Fukufuji                 1  fukufyu01     0.603565
# 5785             Jamie Storr                 1  storrja01     0.574169
# 5080            Gary Roberts                 1  roberga01     0.573914

# %%
linear_svc = LinearSVC()
linear_svc_pred = run_classifier(linear_svc)
# Out:
# Testing LinearSVC
# ----------------------------------------
#
# Training Score: 96.8
# Accuracy with Current HF: 38.89
# F1 Score: 0.61
# Precision Score: 0.92
# Recall Score: 0.57
#
# ----- Predictions -----
#
#                fullName  isInHfPrediction   playerID
# 248        Tom Barrasso                 1  barrato01
# 955       Chris Chelios                 1  chelich01
# 1800     Peter Forsberg                 1  forsbpe01
# 2315      Dominik Hasek                 1  hasekdo01
# 2890        Paul Kariya                 1  kariypa01
# 4367  Scott Niedermayer                 1  niedesc01
# 5229          Joe Sakic                 1  sakicjo01

# %%
decision_tree = DecisionTreeClassifier()
decision_tree_pred = run_classifier(decision_tree)
# Out:
# Testing DecisionTreeClassifier
# ----------------------------------------
#
# Training Score: 99.91
# Accuracy with Current HF: 77.78
# F1 Score: 0.68
# Precision Score: 0.7
# Recall Score: 0.67
#
# ----- Predictions -----
#
#                 fullName  isInHfPrediction   playerID  probability
# 242         Scott Barney                 1  barnesc01          1.0
# 5229           Joe Sakic                 1  sakicjo01          1.0
# 3830       Dean McAmmond                 1  mcammde01          1.0
# 4035      Josef Melichar                 1  melicjo01          1.0
# 4114        Kevin Miller                 1  milleke02          1.0
# 4141         Mike Modano                 1  modanmi01          1.0
# 4314      Markus Naslund                 1  nasluma02          1.0
# 4367   Scott Niedermayer                 1  niedesc01          1.0
# 4437          Adam Oates                 1  oatesad01          1.0
# 4466      Mattias Ohlund                 1  ohlunma01          1.0
# 4476        David Oliver                 1  oliveda01          1.0
# 4563     Justin Papineau                 1  papinju01          1.0
# 4903      Karel Rachunek                 1  rachuka01          1.0
# 4912      Brian Rafalski                 1  rafalbr01          1.0
# 5246     Sergei Samsonov                 1  samsose01          1.0
# 3472        Eric Lindros                 1  lindrer01          1.0
# 5263       Tommi Santala                 1  santato01          1.0
# 5335         Rob Schremp                 1  schrero01          1.0
# 5587          Mark Smith                 1  smithma01          1.0
# 5728    Charlie Stephens                 1  stephch01          1.0
# 5843          Gary Suter                 1  suterga01          1.0
# 5855          Ron Sutter                 1  suttero01          1.0
# 5957    Jocelyn Thibault                 1  thibajo01          1.0
# 6010       Keith Tkachuk                 1  tkachke01          1.0
# 6175         Pat Verbeek                 1  verbepa01          1.0
# 6359        Kay Whitmore                 1  whitmka01          1.0
# 6483          Terry Yake                 1   yakete01          1.0
# 6495    Vitali Yeremeyev                 1  yeremvi01          1.0
# 3478          David Ling                 1   lingda01          1.0
# 3464       Trevor Linden                 1  lindetr01          1.0
# 248         Tom Barrasso                 1  barrato01          1.0
# 1692      Sergei Fedorov                 1  fedorse01          1.0
# 365         Bryan Berard                 1  berarbr01          1.0
# 387   Christian Berglund                 1  berglch01          1.0
# 465            Rob Blake                 1  blakero01          1.0
# 650      Rod Brind'Amour                 1  brindro01          1.0
# 755           Pavel Bure                 1   burepa01          1.0
# 953    Jonathan Cheechoo                 1  cheecjo01          1.0
# 955        Chris Chelios                 1  chelich01          1.0
# 1259         Byron Dafoe                 1  dafoeby01          1.0
# 1322            Jeff Daw                 1    dawje01          1.0
# 1401          Rob DiMaio                 1  dimairo01          1.0
# 1467        Dallas Drake                 1  drakeda01          1.0
# 1469         Kris Draper                 1  drapekr01          1.0
# 1762       Wade Flaherty                 1  flahewa01          1.0
# 3348        John LeClair                 1  leclajo01          1.0
# 1800      Peter Forsberg                 1  forsbpe01          1.0
# 2002           Todd Gill                 1   gillto01          1.0
# 2113         Adam Graves                 1  gravead01          1.0
# 2137          Mark Greig                 1  greigma01          1.0
# 2242       Jeff Hamilton                 1  hamilje01          1.0
# 2315       Dominik Hasek                 1  hasekdo01          1.0
# 2565        Phil Housley                 1  houslph01          1.0
# 2651       Mike Iggulden                 1  iggulmi01          1.0
# 2675       Brayden Irwin                 1  irwinbr01          1.0
# 2733       Jason Jaspers                 1  jaspeja01          1.0
# 2890         Paul Kariya                 1  kariypa01          1.0
# 3087   Vyacheslav Kozlov                 1  kozlovy01          1.0
# 6542        Alex Zhamnov                 1  zhamnal01          1.0

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest_pred = run_classifier(random_forest)
# Out:
# Testing RandomForestClassifier
# ----------------------------------------
#
# Training Score: 99.91
# Accuracy with Current HF: 66.67
# F1 Score: 0.76
# Precision Score: 0.92
# Recall Score: 0.69
#
# ----- Predictions -----
#
#                fullName  isInHfPrediction   playerID  probability
# 5229          Joe Sakic                 1  sakicjo01         0.93
# 2890        Paul Kariya                 1  kariypa01         0.88
# 465           Rob Blake                 1  blakero01         0.87
# 3472       Eric Lindros                 1  lindrer01         0.85
# 4367  Scott Niedermayer                 1  niedesc01         0.85
# 955       Chris Chelios                 1  chelich01         0.82
# 1800     Peter Forsberg                 1  forsbpe01         0.82
# 2315      Dominik Hasek                 1  hasekdo01         0.82
# 1692     Sergei Fedorov                 1  fedorse01         0.80
# 3348       John LeClair                 1  leclajo01         0.80
# 248        Tom Barrasso                 1  barrato01         0.77
# 4314     Markus Naslund                 1  nasluma02         0.70
# 755          Pavel Bure                 1   burepa01         0.70
# 5411   Brendan Shanahan                 1  shanabr01         0.69
# 650     Rod Brind'Amour                 1  brindro01         0.65
# 5843         Gary Suter                 1  suterga01         0.57
# 5138      Cliff Ronning                 1  ronnicl01         0.56

# %% [markdown]
# ## Model Performance ##

# %%
model_performance = pd.DataFrame.from_dict(classifiers, orient='index')
model_performance.sort_values(by='F1 Score', ascending=False)
# Out:
#                         Training Accuracy  F1 Score  Current HoF Accuracy
# GaussianNB                          95.93  0.799149                 94.44
# LogisticRegression                  97.39  0.770006                 66.67
# RandomForestClassifier              99.91  0.762637                 66.67
# MLPClassifier                       97.23  0.747214                 66.67
# KNeighborsClassifier                97.54  0.683827                 44.44
# DecisionTreeClassifier              99.91  0.683091                 77.78
# LinearSVC                           96.80  0.611292                 38.89
# SVC                                 98.32  0.504367                  0.00

# %% [markdown]
# Based on pure statistics, it appears that GaussianNB had the best predictions, but it also seemed to predict a lot more players will make the HoF compared to others, but let's pick this one and see if we can predict who's going to be next in the HoF

# %% [markdown]
# **Generated predictions for GaussianNB**

# %%
gaussian_pred.sort_values(by='probability', ascending=False).head(10)
# Out:
#                fullName  isInHfPrediction   playerID  probability
# 248        Tom Barrasso                 1  barrato01          1.0
# 5229          Joe Sakic                 1  sakicjo01          1.0
# 2890        Paul Kariya                 1  kariypa01          1.0
# 3472       Eric Lindros                 1  lindrer01          1.0
# 2315      Dominik Hasek                 1  hasekdo01          1.0
# 4367  Scott Niedermayer                 1  niedesc01          1.0
# 1800     Peter Forsberg                 1  forsbpe01          1.0
# 1692     Sergei Fedorov                 1  fedorse01          1.0
# 955       Chris Chelios                 1  chelich01          1.0
# 755          Pavel Bure                 1   burepa01          1.0

# %% [markdown]
# **Top 10 predictions with new inductees filtered out**
#
# Since we found out who made the HoF in the years after the dataset supports, let's remove them from the predictions and see who's left

# %%
def filter_out_new_hof(df):
    return df[~df['playerID'].isin(new_hof)].sort_values(by='probability', ascending=False)

filter_out_new_hof(gaussian_pred).head(5)
# Out:
#             fullName  isInHfPrediction   playerID  probability
# 248     Tom Barrasso                 1  barrato01          1.0
# 2890     Paul Kariya                 1  kariypa01          1.0
# 3348    John LeClair                 1  leclajo01          1.0
# 3046     Olaf Kolzig                 1  kolziol01          1.0
# 4314  Markus Naslund                 1  nasluma02          1.0

# %% [markdown]
# Just for fun, let's check the same predictions using Logistic Regression

# %%
filter_out_new_hof(logreg_pred).head(5)
# Out:
#                 fullName  isInHfPrediction   playerID  probability
# 2890         Paul Kariya                 1  kariypa01     0.974604
# 248         Tom Barrasso                 1  barrato01     0.957850
# 3348        John LeClair                 1  leclajo01     0.852859
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.681158
# 650      Rod Brind'Amour                 1  brindro01     0.641168

# %% [markdown]
# Recently, the 2017 inductees were announced, and it we got one of the four correct. The newly added players were: Teemu Selanne, Dave Andreychuk, Mark Recchi and Paul Kariya ( https://www.nhl.com/news/hockey-hall-of-fame-class-of-2017/c-290161438 )
#
# We predicted Paul Kariya, but why not Teemu? Well that's because Teemu retired in 2014 and was playing during the time the dataset was created and we excluded current players from the predictions. What if we add his record to the prediction list, would we have predicted him?

# %%
# Grab his record
teemu = master_df[master_df['playerID'] == 'selante01'][cols]
# Remove cols not needed
teemu.drop(cols_to_drop, axis=1)
# Add his as an eligible player
eligible_players = eligible_players.append(teemu)
# Add him to the test set
X_player_test = eligible_players.drop(cols_to_drop, axis=1).copy()

# %%
# Rerun the prediction using our existing NN classifier
(_, all_nn_pred) = show_prediction_with_probabilities(nn, X_player_test, display=False)
filter_out_new_hof(all_nn_pred).head(10)
# Out:
#                 fullName  isInHfPrediction   playerID  probability
# 5379       Teemu Selanne                 1  selante01     0.959631
# 2890         Paul Kariya                 1  kariypa01     0.959242
# 248         Tom Barrasso                 1  barrato01     0.916740
# 3348        John LeClair                 1  leclajo01     0.804932
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.710213
# 6180         Mike Vernon                 1  vernomi01     0.637327
# 650      Rod Brind'Amour                 1  brindro01     0.619292
# 4515        Chris Osgood                 1  osgooch01     0.540809
# 3046         Olaf Kolzig                 1  kolziol01     0.501048
# 4314      Markus Naslund                 0  nasluma02     0.490782

# %%
# Rerun the prediction using our existing Gaussian classifier
(_, all_gaussian_pred) = show_prediction_with_probabilities(gaussian, X_player_test, display=False)
filter_out_new_hof(all_gaussian_pred).head(10)
# Out:
#                 fullName  isInHfPrediction   playerID  probability
# 5379       Teemu Selanne                 1  selante01     1.000000
# 2890         Paul Kariya                 1  kariypa01     1.000000
# 3348        John LeClair                 1  leclajo01     1.000000
# 248         Tom Barrasso                 1  barrato01     1.000000
# 3046         Olaf Kolzig                 1  kolziol01     1.000000
# 4314      Markus Naslund                 1  nasluma02     1.000000
# 6139  John Vanbiesbrouck                 1  vanbijo01     1.000000
# 650      Rod Brind'Amour                 1  brindro01     1.000000
# 6180         Mike Vernon                 1  vernomi01     1.000000
# 4976       Richie Regehr                 1  regehri01     0.999999

# %%
(_, all_logreg_pred) = show_prediction_with_probabilities(logreg, X_player_test, display=False)
filter_out_new_hof(all_logreg_pred).head(10)
# Out:
#                 fullName  isInHfPrediction   playerID  probability
# 5379       Teemu Selanne                 1  selante01     0.977575
# 2890         Paul Kariya                 1  kariypa01     0.974604
# 248         Tom Barrasso                 1  barrato01     0.957850
# 3348        John LeClair                 1  leclajo01     0.852859
# 6139  John Vanbiesbrouck                 1  vanbijo01     0.681158
# 650      Rod Brind'Amour                 1  brindro01     0.641168
# 6180         Mike Vernon                 1  vernomi01     0.607612
# 3046         Olaf Kolzig                 1  kolziol01     0.532427
# 4515        Chris Osgood                 1  osgooch01     0.524728
# 4314      Markus Naslund                 0  nasluma02     0.497883

# %% [markdown]
# You can see that both classifiers now include Teemu in the top 4. But what about Mark Recchi and Dave Andreychuk?

# %%
missing_hof = ['andreda01', 'recchma01']
master_df[master_df['playerID'].isin(missing_hof)]
# Out:
#        playerID  birthCountry hofID firstName    lastName  height  weight  \
# 96    andreda01             1   NaN      Dave  Andreychuk    76.0   220.0
# 4957  recchma01             1   NaN      Mark      Recchi    70.0   195.0
#
#       shootCatch  firstNHL  lastNHL  pos  nhlLength  isInHf         fullName  \
# 96             0    1982.0   2005.0    4       24.0       0  Dave Andreychuk
# 4957           1    1988.0   2010.0    5       23.0       0      Mark Recchi
#
#       awardCount
# 96           0.0
# 4957         1.0

# %%
all_gaussian_pred[all_gaussian_pred['playerID'].isin(missing_hof)]
# Out:
#              fullName  isInHfPrediction   playerID  probability
# 96    Dave Andreychuk                 0  andreda01     0.184111
# 4957      Mark Recchi                 1  recchma01     0.756262

# %%
all_logreg_pred[all_logreg_pred['playerID'].isin(missing_hof)]
# Out:
#              fullName  isInHfPrediction   playerID  probability
# 96    Dave Andreychuk                 0  andreda01     0.102469
# 4957      Mark Recchi                 0  recchma01     0.219114

# %% [markdown]
# You can see that at least Gaussian picked Recchi for the HoF ( just not as confident as other players ), but neither predicted Andreychuk and also gave him a very low probability.
#
# If you look at the correlation matrix, you'll notice it heavily correlated the number of awards to if you made the HoF and since Andreychuk didn't have any awards, it's understandable he didn't get considered using our algorithm. So why was he picked?
#
# It turns out that Andreychuk, "had been the only retired player with at least 600 goals (640) not in the Hockey Hall of Fame". Our algorithm doesn't take into account positional statistics like goals/assists/points/+-/etc to keep this somewhat simple, but something to consider for a future version.
